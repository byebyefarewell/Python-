# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# %%
data = pd.read_csv('C:/Data/stopword.csv')
# Out:
# C:\Users\Jo Youngsang\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (22,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data['company_profile'].fillna('', inplace=True)
data['description'].fillna('', inplace=True)
data['requirements'].fillna('', inplace=True)
data.head()
# Out:
#    Unnamed: 0  X1  job_id                                      title  \
# 0           1   0       1                           Marketing Intern
# 1           2   1       2  Customer Service - Cloud Video Production
# 2           3   3       4          Account Executive - Washington DC
# 3           4   4       5                        Bill Review Manager
# 4           5   5       6                           Accounting Clerk
#
#              location department salary_range  \
# 0    US, NY, New York  Marketing          NaN
# 1      NZ, , Auckland    Success          NaN
# 2  US, DC, Washington      Sales          NaN
# 3  US, FL, Fort Worth        NaN          NaN
# 4             US, MD,        NaN          NaN
#
#                                      company_profile  \
# 0  food weve creat groundbreak awardwin cook site...
# 1  second world cloud video product servic second...
# 2  passion improv qualiti life geographi heart ev...
# 3  spotsourc solut llc global human capit manag c...
# 4
#
#                                          description  \
# 0  food fastgrow jame beard awardwin onlin food c...
# 1  organis focus vibrant awesomedo passion custom...
# 2  compani esri environment system research insti...
# 3  job titl item review managerloc fort worth txu...
# 4  job overviewapex environment consult firm offe...
#
#                                         requirements  ... sal_diff  \
# 0  experi content manag system major plu blog cou...  ...      NaN
# 1  expect youyour key respons commun client secon...  ...      NaN
# 2  educationuabacheloru masteru gi busi administr...  ...      NaN
# 3  qualificationsrn licens state texasdiploma bac...  ...      NaN
# 4                                                     ...      NaN
#
#                   industry_1  department_1            function_1 ISO  \
# 0                        NaN     Marketing             Marketing  US
# 1  Marketing and Advertising       Success      Customer Service  NZ
# 2          Computer Software         Sales                 Sales  US
# 3     Hospital & Health Care           NaN  Health Care Provider  US
# 4                        NaN           NaN                   NaN  US
#
#                      Nation Continent description_specified  \
# 0  United States of America  Americas                     1
# 1               New Zealand   Oceania                     1
# 2  United States of America  Americas                     1
# 3  United States of America  Americas                     1
# 4  United States of America  Americas                     1
#
#   requirements_specified  benefits_specified
# 0                      1                   0
# 1                      1                   1
# 2                      1                   1
# 3                      1                   1
# 4                      0                   0
#
# [5 rows x 34 columns]

# %%
cp = pd.read_csv('C:/Data/cp.csv')
ds = pd.read_csv('C:/Data/ds.csv')
rq = pd.read_csv('C:/Data/rq.csv')

# %%
cp
# Out:
#     topic1      topic2   topic3   topic4   topic5   topic6   topic7   topic8  \
# 0  product      servic       ua    digit      amp  process     work     home
# 1    build     recruit     food    world      job    solut     team  qualiti
# 2   commun        busi      web    chang    secur    deliv    peopl   custom
# 3   servic     consult    video     busi      get   custom     make   servic
# 4   custom       manag     team    engag     help   commun  develop   provid
# 5  compani      talent    world   global  teacher     busi   design     valu
# 6   system    industri  develop    think     safe    manag  compani   beauti
# 7    peopl      client      use    solut   abroad   improv  employe   health
# 8   believ      provid  compani    creat    close   client    learn    ensur
# 9     team  profession     home  content   servic    drive     look    everi
#
#      topic9    topic10  topic11    topic12     topic13     topic14   topic15
# 0   compani     servic  compani      peopl       engin        work      team
# 1   product     market     work       work  manufactur       right   compani
# 2   develop     provid  employe       team      candid        educ      game
# 3  platform    compani   servic       weur     compani        long    social
# 4   softwar     client   financ        new       posit        wish      work
# 5    custom        amp   provid       grow        high       great        us
# 6       web  technolog   employ      brand        time       ensur     mobil
# 7      busi      solut   consum         us     technic       cours     peopl
# 8      open       busi  benefit  technolog      highli     recruit     great
# 9    provid    recruit     team    startup        full  apprentice  shipmake

# %%
ds
# Out:
#      topic1    topic2  topic3       topic4   topic5   topic6   topic7  \
# 0    custom      sale  websit         cost  develop     work    manag
# 1      mail        ua     job       travel     data     team     busi
# 2      file    custom  search          get    engin     look   client
# 3    servic   product  experi      student   system     help     team
# 4  document    servic    free         paid  technic     make  develop
# 5      team    market    year      monthli  softwar    peopl  project
# 6    candid       new   appli         play  project  compani  account
# 7     level      busi   relev         asia     team       us  financi
# 8     right  prospect   click          kid     test      get   execut
# 9      part    client    open  loanscredit   applic   custom     plan
#
#     topic8   topic9  topic10 topic11   topic12   topic13  topic14   topic15
# 0    posit   design    manag    work    candid     video  patient    market
# 1  compani  develop     oper    team      work   product   provid     media
# 2     work  product   includ  servic       amp     shall  student    social
# 3   servic     team   requir  client      look      week   health   content
# 4   includ     work    ensur  custom   recruit  deliveri    medic  campaign
# 5     hour      web  process   posit      role      test     work     manag
# 6   experi    mobil     work    look    experi     daili   commun     brand
# 7   employ     user  support   train    career    assign   school    commun
# 8     home   experi  product   skill  opportun      site   clinic     digit
# 9  benefit     look  respons    abil     pleas    custom   servic     onlin

# %%
rq
# Out:
#       topic1   topic2   topic3    topic4   topic5   topic6   topic7   topic8  \
# 0      shall   custom   market        ua     sale   experi     work     work
# 1      video   servic   social      work   experi     year     look    skill
# 2     intern   commun    media     skill     busi    degre     team  diploma
# 3       news    skill   experi     peopl     abil    engin   experi   school
# 4    languag   experi   commun    includ    manag      job    learn   experi
# 5  broadcast     work  english  skillsua   record    appli      get   custom
# 6     produc    phone    onlin   support     year    relat     make   servic
# 7       edit   comput    write       may    skill   websit     love  equival
# 8     includ  support    digit    provid    track    posit  passion    relat
# 9    product     must  content    access  success  minimum     need   requir
#
#     topic9   topic10     topic11   topic12   topic13 topic14  topic15
# 0    manag    requir      design   univers    experi    must    skill
# 1  project   perform      experi     teach      data    work     work
# 2     team      work     develop     degre    system     abl   experi
# 3  develop       job         web    experi      test   drive   commun
# 4   client       may    knowledg    prefer   develop  requir     abil
# 5  product      abil        work     tesol     manag  licens    manag
# 6   market   employe        year     celta   softwar  experi     year
# 7     busi  maintain        html  passport  knowledg    year  written
# 8     work     andor  javascript  required   technic  driver    excel
# 9     plan      oper      applic    holder   databas   valid    degre
